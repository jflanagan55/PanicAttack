# %% [markdown]
# Research Question: Do People who suffer from Panic Attacks that go to therapy experience shorter, less frequent Panic Attacks?
#
#  Null Hypothesis H₀: There is no difference in the frequency and length of panic attacks, whether someone goes to Therapy or not.
#
#  Alternative Hypothesos: H₁: Panic Attack Sufferers who go to Therapy experience shorter and less frequent Panic Attacks than their Counterparts who do not attend Therapy

# %%
import pandas as pd
df = pd.read_csv('panic_attack_dataset.csv')
therapyGroup = df[df["Therapy"] == "Yes"]
noTherapyGroup = df[df["Therapy"]=="No"]

# %%
import matplotlib.pyplot as plt

therapyGroup['Panic_Attack_Frequency'].plot(kind='hist', bins=10, edgecolor='black')

plt.xlabel("Panic Attacks Per Month")
plt.ylabel('Number of People')
plt.title('Panic Attack Frequency (Therapy Group)')
# Out:
# Text(0.5, 1.0, 'Panic Attack Frequency (Therapy Group)')

# %%
noTherapyGroup['Panic_Attack_Frequency'].plot(kind='hist', bins=10, edgecolor='black')

plt.xlabel("Panic Attacks Per Month")
plt.ylabel('Number of People')
plt.title('Panic Attack Frequency ( No Therapy Group)')
# Out:
# Text(0.5, 1.0, 'Panic Attack Frequency ( No Therapy Group)')

# %%
therapyGroup['Duration_Minutes'].plot(kind='hist', bins=22, edgecolor='black')

plt.xlabel("Length of Panic Attack in Minutes")
plt.ylabel('Number of People')
plt.title('Average Panic Attack Length (Therapy Group)')
# Out:
# Text(0.5, 1.0, 'Average Panic Attack Length (Therapy Group)')

# %%
noTherapyGroup['Duration_Minutes'].plot(kind='hist', bins=22, edgecolor='black')

plt.xlabel("Length of Panic Attack in Minutes")
plt.ylabel('Number of People')
plt.title('Average Panic Attack Length (Therapy Group)')
# Out:
# Text(0.5, 1.0, 'Average Panic Attack Length (Therapy Group)')
